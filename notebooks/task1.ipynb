# %% [markdown]
# Step 1: Gather the "Patent Set"
#     Source Dataset: SampleGloria_Pat_GlinerLabels.parquet
#     Columns: patent_id, term
#     Action: 1. Group by patent_id and term.
#     2. Count the occurrences to get frequency in patent.
#     3. This gives you your first "set" of terms for every patent.
#     output -> patent_id, term, freq_in_patent

# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/raw/SampleGloria_Pat_GlinerLabels.parquet')
df.head()
# Out:
#   patent_id           term                 label GrantedDate  year  \
# 0   7662783       treating  Health Care Activity  2010-02-16  2010
# 1   7662783    solid tumor   Disease or Syndrome  2010-02-16  2010
# 2   7662783        patient                 Human  2010-02-16  2010
# 3   7662783     comprising  Laboratory Procedure  2010-02-16  2010
# 4   7662783  administering  Health Care Activity  2010-02-16  2010
#
#    num_claims  withdrawn
# 0         9.0        0.0
# 1         9.0        0.0
# 2         9.0        0.0
# 3         9.0        0.0
# 4         9.0        0.0

# %%
patent_terms = (
    df.groupby(["patent_id", "term"])
      .size()
      .reset_index(name="freq_in_patent")
)
patent_terms.freq_in_patent.unique()
# Out:
# array([1, 2, 4, 3, 6, 5])

# %% [markdown]
# Step 2: Bridge to the Papers
#     Source Dataset: SampleGloria_Link_PmidOa.parquet
#     Columns: patent_id, pmid
#     Action: 1. Filter the pmid column to remove empty rows.
#     2. Crucial: Extract the numeric ID from the end of the URL in the pmid column (e.g., from .../8623768 get 8623768).
#     3. This tells you which Paper IDs belong to which Patent ID.
#     output: "patent_id" and "pmid" (with just digit $ from the orginal string)

# %%
df = pd.read_parquet('../data/raw/SampleGloria_Link_PmidOa.parquet')
df.head(10)
# Out:
#       openalex patent_id          oaid  scipat  confscore  ppp_score  \
# 0   W100031634   8145998  1.000316e+08     0.0        8.0        NaN
# 1   W100155009   7943636  1.001550e+08     0.0       10.0        NaN
# 2  W1002574413   7851144  1.002574e+09     0.0        4.0        NaN
# 3   W100376596   8008547  1.003766e+08     0.0       10.0        NaN
# 4    W10039931   8229677  1.003993e+07     0.0       10.0        NaN
# 5   W100681333   7662783  1.006813e+08     0.0       10.0        NaN
# 6  W1006955200   8178497  1.006955e+09     0.0        2.0        NaN
# 7  W1008795863   7741269  1.008796e+09     0.0        1.0        NaN
# 8   W101281971   8119608  1.012820e+08     0.0       10.0        NaN
# 9   W101336797   8222211  1.013368e+08     0.0        2.0        NaN
#
#                                        pmid
# 0                                       NaN
# 1   https://pubmed.ncbi.nlm.nih.gov/8623768
# 2   https://pubmed.ncbi.nlm.nih.gov/3431463
# 3   https://pubmed.ncbi.nlm.nih.gov/3273636
# 4  https://pubmed.ncbi.nlm.nih.gov/11084856
# 5  https://pubmed.ncbi.nlm.nih.gov/11191056
# 6                                       NaN
# 7                                       NaN
# 8  https://pubmed.ncbi.nlm.nih.gov/11570495
# 9                                       NaN

# %%
df_cleaned = df.dropna(subset=["pmid"])
df_cleaned["pmid"] = df_cleaned["pmid"].str.extract(r'(\d+)$').astype(int)
# drop duplicate (patent_id, pmid) pairs that arise from multiple matching sources
df_cleaned = df_cleaned.drop_duplicates(subset=["patent_id", "pmid"])
df_cleaned.head(20)
# Out:
#        openalex patent_id          oaid  scipat  confscore  ppp_score  \
# 1    W100155009   7943636  1.001550e+08     0.0       10.0        NaN
# 2   W1002574413   7851144  1.002574e+09     0.0        4.0        NaN
# 3    W100376596   8008547  1.003766e+08     0.0       10.0        NaN
# 4     W10039931   8229677  1.003993e+07     0.0       10.0        NaN
# 5    W100681333   7662783  1.006813e+08     0.0       10.0        NaN
# 8    W101281971   8119608  1.012820e+08     0.0       10.0        NaN
# 12  W1021218198   8008547  1.021218e+09     0.0       10.0        NaN
# 13  W1021218198   8173393  1.021218e+09     0.0       10.0        NaN
# 16   W104312724   7785803  1.043127e+08     0.0       10.0        NaN
# 17   W105118458   7951356  1.051185e+08     0.0       10.0        NaN
# 18    W10594096   8008004  1.059410e+07     0.0        5.0        NaN
# 20   W108603584   7741269  1.086036e+08     0.0       10.0        NaN
# 23   W111365110   8071110  1.113651e+08     0.0       10.0        NaN
# 25   W113221882   8008004  1.132219e+08     0.0       10.0        NaN
# 26  W1155235703   8071320  1.155236e+09     0.0        6.0        NaN
# 27  W1156038375   8084587  1.156038e+09     0.0        8.0        NaN
# 31   W118252167   7781419  1.182522e+08     0.0       10.0        NaN
# 37   W120703973   8273700  1.207040e+08     0.0       10.0        NaN
# 38  W1233451781   8114843  1.233452e+09     0.0        4.0        NaN
# 39  W1234774043   7951356  1.234774e+09     0.0       10.0        NaN
#
#         pmid
# 1    8623768
# 2    3431463
# 3    3273636
# 4   11084856
# 5   11191056
# 8   11570495
# 12   2828857
# 13   2828857
# 16   8774132
# 17   3061932
# 18   3724461
# 20   7436633
# 23   8861019
# 25   3894007
# 26   6318024
# 27   2314247
# 31   1343452
# 37   7529176
# 38   8081712
# 39   2920216

# %% [markdown]
# Step 3: Gather the "Cited Papers Set"
#
#     Source Dataset: SampleGloria_Pmed_GlinerLabels.parquet
#
#     Columns: pmid, term
#
#     Action: 1. Using the mapping from Step 2, link these terms back to their patent_id.
#     2. Group by patent_id and term.
#     3. Count the occurrences to get frequency in cited papers. (Note: If a patent cites 3 papers, this is the total count across all 3).

# %%
df_pmed = pd.read_parquet("../data/raw/SampleGloria_Pmed_GlinerLabels.parquet")
merged_df = pd.merge(df_pmed, df_cleaned, on=["pmid"], how="inner")
merged_df 
count_fre_in_pmid = (
    merged_df.groupby(["pmid", "term"])
      .size()
      .reset_index(name="freq_in_pmdi")
)
count_fre_in_pmid.head()
# Out:
#       pmid            term  freq_in_pmdi
# 0  2403803  administration             1
# 1  2403803          animal             1
# 2  2403803        antibody             1
# 3  2403803       antitumor             1
# 4  2403803        approach             1

# %% [markdown]
# Find the focal term

# %%
# Keep pmid in the groupby
cited_terms = (
    merged_df.groupby(["patent_id", "pmid", "term"])
             .size()
             .reset_index(name="freq_in_cited_paper")
)

# %%
cited_terms
# Out:
#       patent_id      pmid         term  freq_in_cited_paper
# 0       7662783  11387236     activity                    1
# 1       7662783  11387236     adhesion                    1
# 2       7662783  11387236        alpha                    1
# 3       7662783  11387236  alpha5beta1                    1
# 4       7662783  11387236          and                    1
# ...         ...       ...          ...                  ...
# 31287   8338460  12323058     reaction                    1
# 31288   8338460  12323058   simplicity                    1
# 31289   8338460  12323058       sulfur                    1
# 31290   8338460  12323058       system                    1
# 31291   8338460  12323058   toleration                    1
#
# [31292 rows x 4 columns]

# %%
# Merge on patent_id + term → keeps only terms that appear in both
focal_terms = patent_terms.merge(cited_terms, on=["patent_id", "term"], how="inner")

# %%
# Save focal terms with pmid before aggregation
focal_terms_with_pmid = focal_terms[['patent_id', 'term', 'pmid']].rename(columns={'term': 'focal_term'})
focal_terms_with_pmid.to_parquet("../output/focal_terms_with_pmid.parquet", index=False)
focal_terms_with_pmid.head()
# Out:
#   patent_id  focal_term      pmid
# 0   7662783       alpha  11387236
# 1   7662783  antagonist  11387236
# 2   7662783        cell  11535623
# 3   7662783        cell  12071856
# 4   7662783        cell  12454288

# %%
focal_terms
# Out:
#      patent_id           term  freq_in_patent      pmid  freq_in_cited_paper
# 0      7662783          alpha               1  11387236                    1
# 1      7662783     antagonist               2  11387236                    1
# 2      7662783           cell               1  11535623                    1
# 3      7662783           cell               1  12071856                    1
# 4      7662783           cell               1  12454288                    1
# ...        ...            ...             ...       ...                  ...
# 1738   8309961          oxide               3  12764192                    1
# 1739   8309961         second               1  12764192                    1
# 1740   8309961  semiconductor               2  12764192                    1
# 1741   8318804           cell               1  16557477                    1
# 1742   8318804          virus               1  16189083                    1
#
# [1743 rows x 5 columns]

# %%
focal_terms = ( focal_terms.groupby(["patent_id", "term"], as_index=False) .agg( freq_in_patent=("freq_in_patent", "first"), freq_in_cited_paper=("freq_in_cited_paper", "sum"), ) )
focal_terms.rename(columns={'term': 'focal_term'}, inplace=True)

# %%
focal_terms
# Out:
#     patent_id     focal_term  freq_in_patent  freq_in_cited_paper
# 0     7662783          alpha               1                    1
# 1     7662783     antagonist               2                    1
# 2     7662783           cell               1                    6
# 3     7662783       collagen               1                    3
# 4     7662783          colon               1                    1
# ..        ...            ...             ...                  ...
# 785   8309961          oxide               3                    1
# 786   8309961         second               1                    1
# 787   8309961  semiconductor               2                    1
# 788   8318804           cell               1                    1
# 789   8318804          virus               1                    1
#
# [790 rows x 4 columns]

# %%
focal_terms.to_parquet("./output_dataset/focal_terms.parquet")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 focal_terms.to_parquet("./output_dataset/focal_terms.parquet")
#
# File ~/Library/Caches/pypoetry/virtualenvs/hiwi-02P-lfTy-py3.12/lib/python3.12/site-packages/pandas/core/frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3131 >>> content = f.read()
#    3132 """
#    3133 from pandas.io.parquet import to_parquet
# -> 3135 return to_parquet(
#    3136     self,
#    3137     path,
#    3138     engine,
#    3139     compression=compression,
#    3140     index=index,
#    3141     partition_cols=partition_cols,
#    3142     storage_options=storage_options,
#    3143     filesystem=filesystem,
#    3144     **kwargs,
#    3145 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/hiwi-02P-lfTy-py3.12/lib/python3.12/site-packages/pandas/io/parquet.py:490, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 490 impl.write(
#     491     df,
#     492     path_or_buf,
#     493     compression=compression,
#     494     index=index,
#     495     partition_cols=partition_cols,
#     496     storage_options=storage_options,
#     497     filesystem=filesystem,
#     498     **kwargs,
#     499 )
#     501 if path is None:
#     502     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/Library/Caches/pypoetry/virtualenvs/hiwi-02P-lfTy-py3.12/lib/python3.12/site-packages/pandas/io/parquet.py:199, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     196     merged_metadata = {**existing_metadata, **df_metadata}
#     197     table = table.replace_schema_metadata(merged_metadata)
# --> 199 path_or_handle, handles, filesystem = _get_path_or_handle(
#     200     path,
#     201     filesystem,
#     202     storage_options=storage_options,
#     203     mode="wb",
#     204     is_dir=partition_cols is not None,
#     205 )
#     206 if (
#     207     isinstance(path_or_handle, io.BufferedWriter)
#     208     and hasattr(path_or_handle, "name")
#     209     and isinstance(path_or_handle.name, (str, bytes))
#     210 ):
#     211     if isinstance(path_or_handle.name, bytes):
#
# File ~/Library/Caches/pypoetry/virtualenvs/hiwi-02P-lfTy-py3.12/lib/python3.12/site-packages/pandas/io/parquet.py:141, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     131 handles = None
#     132 if (
#     133     not fs
#     134     and not is_dir
#    (...)    139     # fsspec resources can also point to directories
#     140     # this branch is used for example when reading from non-fsspec URLs
# --> 141     handles = get_handle(
#     142         path_or_handle, mode, is_text=False, storage_options=storage_options
#     143     )
#     144     fs = None
#     145     path_or_handle = handles.handle
#
# File ~/Library/Caches/pypoetry/virtualenvs/hiwi-02P-lfTy-py3.12/lib/python3.12/site-packages/pandas/io/common.py:793, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     791 # Only for write methods
#     792 if "r" not in mode and is_path:
# --> 793     check_parent_directory(str(handle))
#     795 if compression:
#     796     if compression != "zstd":
#     797         # compression libraries do not like an explicit text-mode
#
# File ~/Library/Caches/pypoetry/virtualenvs/hiwi-02P-lfTy-py3.12/lib/python3.12/site-packages/pandas/io/common.py:652, in check_parent_directory(path)
#     650 parent = Path(path).parent
#     651 if not parent.is_dir():
# --> 652     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output_dataset'
